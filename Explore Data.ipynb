# %%
import pandas as pd

train = pd.read_pickle('train_rolling.pkl')
test = pd.read_pickle('test_rolling.pkl')

print(train.info())
print(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41891 entries, 0 to 47951
# Columns: 291 entries, norm close to next point norm close
# dtypes: float64(291)
# memory usage: 93.3 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7751 entries, 0 to 8496
# Columns: 291 entries, norm close to next point norm close
# dtypes: float64(291)
# memory usage: 17.3 MB
# None

# %%
train.head()
# Out:
#    norm close  norm close 1  norm volume 1  norm close 2  norm volume 2  \
# 0    0.000707     -0.002827       0.003928     -0.012014       0.023536
# 1   -0.000708     -0.009915       0.023696     -0.009915       0.028309
# 2   -0.008511     -0.008511       0.028420     -0.008511       0.000000
# 3   -0.001429     -0.001429       0.000000     -0.001429       0.000000
# 4    0.000000      0.000000       0.000000     -0.007153       0.001394
#
#    norm close 3  norm volume 3  norm close 4  norm volume 4  norm close 5  \
# 0     -0.012014       0.028118     -0.012014       0.000000     -0.012014
# 1     -0.009915       0.000000     -0.009915       0.000000     -0.016997
# 2     -0.008511       0.000000     -0.015603       0.001361     -0.009929
# 3     -0.008571       0.001364     -0.002857       0.000070     -0.009286
# 4     -0.001431       0.000071     -0.007868       0.004731      0.008584
#
#            ...            norm close 141  norm volume 141  norm close 142  \
# ...
