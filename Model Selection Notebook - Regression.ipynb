# %%
# %matplotlib inline
import regression_rolling

regression_rolling.run(column_set='pid', train_delta=False, scale=True)
regression_rolling.run(column_set='pid', train_delta=True, scale=True)
regression_rolling.run(column_set='pid', train_delta=False, scale=False)
regression_rolling.run(column_set='pid', train_delta=True, scale=False)
# Out:
# 0.18.2
# regression_rolling.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X['norm close 143 d'] = df['norm close 143'] - df['norm close 142']
# regression_rolling.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   (df['norm close 142'] - df['norm close 141']))
# regression_rolling.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X['norm volume 143 d'] = df['norm volume 143'] - df['norm volume 142']
# regression_rolling.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   (df['norm volume 142'] - df['norm volume 141']))
# (41891, 7)
# fit sgd: 0.095273
# fit sgd_huber: 0.084441
# fit ridge: 0.095689
# fit br: 0.026830
# fit etr: 1.103527
# (7751, 7)
# predict sgd: 0.000457
# predict sgd_huber: 0.000510
# predict ridge: 0.000286
# predict br: 0.000242
# predict etr: 0.110379
# 0.18.2
# (41891, 7)
# fit sgd: 0.084515
# fit sgd_huber: 0.083514
# fit ridge: 0.095879
# fit br: 0.032152
# fit etr: 1.153901
# (7751, 7)
# predict sgd: 0.003333
# predict sgd_huber: 0.001609
# predict ridge: 0.000209
# predict br: 0.001576
# predict etr: 0.132646
# 0.18.2
# (41891, 7)
# fit sgd: 0.087098
# fit sgd_huber: 0.084532
# fit ridge: 0.079077
# fit br: 0.025991
# fit etr: 0.989461
# (7751, 7)
# predict sgd: 0.002080
# predict sgd_huber: 0.000358
# predict ridge: 0.000285
# predict br: 0.000276
# predict etr: 0.129628
# 0.18.2
# (41891, 7)
# fit sgd: 0.086789
# fit sgd_huber: 0.086419
# fit ridge: 0.115721
# fit br: 0.077032
# fit etr: 1.193088
# (7751, 7)
# predict sgd: 0.001814
# predict sgd_huber: 0.000302
# predict ridge: 0.000272
# predict br: 0.000264
# predict etr: 0.151797

# %%
regression_rolling.run(column_set='raw', train_delta=False, scale=True)
regression_rolling.run(column_set='raw', train_delta=True, scale=True)
regression_rolling.run(column_set='raw', train_delta=False, scale=False)
regression_rolling.run(column_set='raw', train_delta=True, scale=False)
# Out:
# 0.18.2
# (41891, 289)
# fit sgd: 0.631441
# fit sgd_huber: 0.550354
# fit ridge: 3.971321
# fit br: 2.809251
# fit etr: 29.344312
# (7751, 289)
# predict sgd: 0.007620
# predict sgd_huber: 0.007216
# predict ridge: 0.006919
# predict br: 0.006798
# predict etr: 0.112159
# 0.18.2
# (41891, 289)
# fit sgd: 0.554197
# fit sgd_huber: 0.552340
# fit ridge: 4.035293
# fit br: 2.670514
# fit etr: 94.066924
# (7751, 289)
# predict sgd: 0.013469
# predict sgd_huber: 0.012941
# predict ridge: 0.012157
# predict br: 0.006746
# predict etr: 0.226132
# 0.18.2
# (41891, 289)
# fit sgd: 0.579469
# fit sgd_huber: 0.577569
# fit ridge: 4.265483
# fit br: 2.813453
# fit etr: 30.992333
# (7751, 289)
# predict sgd: 0.007272
# predict sgd_huber: 0.007088
# predict ridge: 0.006726
# predict br: 0.006680
# predict etr: 0.136731
# 0.18.2
# (41891, 289)
# fit sgd: 0.558236
# fit sgd_huber: 0.559821
# fit ridge: 3.976542
# fit br: 2.526543
# fit etr: 100.116003
# (7751, 289)
# predict sgd: 0.007853
# predict sgd_huber: 0.007485
# predict ridge: 0.007521
# predict br: 0.022499
# predict etr: 0.268832

# %%
# %matplotlib inline
import regression_rolling_mlp

regression_rolling_mlp.run(column_set='raw', train_delta=True, scale=True, evals=20)
# Out:
# 0.18.2
# (41891, 289)
# (7751, 289)
# (5, 2)
# score: -10.007955; time: 5.275374
# (20, 12, 4)
# score: -0.072487; time: 18.005799
# (100, 57, 14)
# score: -0.038493; time: 40.125355
# (5, 3)
# score: -1.395927; time: 5.112147
# (55, 30, 5)
# score: -0.003635; time: 12.880751
# (15, 7)
# score: -0.004490; time: 9.222304
# (60, 36, 12)
# score: -0.049085; time: 32.091218
# (20, 16, 12, 8, 4)
# score: -0.061015; time: 12.237727
# (95, 78, 61, 44, 27, 10)
# score: -0.016127; time: 20.836952
# (45, 33, 21, 9)
# score: -0.000904; time: 16.178187
# (40, 29, 18, 7)
# score: 0.000007; time: 9.412128
# (100, 62, 24)
# score: -0.000303; time: 42.002320
# (35, 27, 19, 11, 3)
# score: -0.043883; time: 25.588021
# (25, 16, 7)
# score: -0.005640; time: 13.950466
# (10, 5)
# score: -5.326441; time: 4.259106
# (40, 20)
# score: -0.101780; time: 25.404911
# (25, 18, 11, 4)
# score: 0.000059; time: 13.895122
# (95, 51, 7)
# score: -0.111415; time: 36.078863
# (65, 39, 13)
# score: -0.018640; time: 37.491006
# (70, 50, 30, 10)
# score: -0.004344; time: 23.706610
# {'first_layer_size': 25.0, 'alpha': 0.09801005924190612, 'layer_decay': 0.24788103373599762}
# (25, 18, 11, 4)
